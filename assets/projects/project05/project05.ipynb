# %% [markdown]
# ## Project 05: Wikipedia Page Histories
#
# - **Due**: (essay and project) Tuesday, 4 December 2018; 12:00pm
# - **Total Points**: 350
#     - selected and described a coherent corpus for analysis, 40 points
#     - completed a thoughtful, well-written essay on your topic, 320 points
#     - oral presentation is clear and rehearsed, 40 points
#
# This projects serves as the "final" project for the semester. It has several
# components that we will build up to through the final week of classes. You must
# again create a set of interactive webpages, as in Projects 3 and 4, but this
# time the set should be smaller and more focused. At the same time, your analysis
# will also include information about page histories.
#
# Here are the steps that you should take, roughly in order, for the project:
#
# 1. Run my sample code below exactly as-is. This will create a page for the page
# histories of 6 well-known philosophers. Click around and see all of the information
# that is shown for the pages. Note that I have manually written the pages that I want
# to include as a text file.
# 2. Select a topic that you want to study for this analysis, which should contain
# anywhere from about 30-200 pages. Start by filling in just a few links and doing
# another test run. Look at the pages and think about what information is captured
# and shown.
# 3. Finish filling in the links and having Python pull all of the data. You should
# now have a reasonable looking corpus to study.
# 4. Now, write a short essay about the collection, the methods you used, and
# interesting patterns. Connect this with some other literature on your topic of
# interest and include citations. Note that this is the largest component of your
# grade! I expect somewhere around 1000-1500 words of content. Please write this in
# either LaTeX or Word.
# 5. In class on December 4th, the website and essay are due. That day we will
# put your essay into the index page of your site and show you how to publish your
# results.
# 6. On the last day of class, December 6th, you will briefly present your site to
# rest of the class.
#
# **Make sure to hand this file, your list of pages, your essay, and the entire website,
# online on GitHub prior to the due date.**

# %% [markdown]
# ### Application
#
# The only thing you need to change with the code this time is the parameter
# `page_name`. Otherwise all of your changes will come from changing the data
# found in the file `page-names.txt`.

# %%
import wiki
import wikitext
import wikihistory

# %%
with open('page-names.txt', 'rt', encoding='UTF-8') as finput:
    links = [x for x in finput.read().splitlines() if x]

# %%
links
# Out:
# ['Plato', 'Aristotle', 'Paris_Agreement']

# %%
wcorp = wikitext.WikiCorpus(links, num_clusters=2)
# Out:
# Pulling data from MediaWiki API: 'Plato'
# Pulling data from MediaWiki API: 'Aristotle'
# Pulling data from MediaWiki API: 'Paris_Agreement'
# /anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
wikitext.wiki_text_explorer(wcorp, page_name="Philosophy")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
wikihistory.wiki_text_explore_page(wcorp, page_name="Philosophy")
# Out:
# Loaded 1000 revisions, through 2012-09-30T20:24:03Z
# Loaded 1500 revisions, through 2009-10-05T18:31:23Z
# Loaded 2000 revisions, through 2008-09-03T02:53:23Z
# Loaded 2500 revisions, through 2007-05-11T15:36:14Z
# Loaded 3000 revisions, through 2007-03-06T01:16:24Z
# Loaded 3500 revisions, through 2007-01-06T14:05:16Z
# Loaded 4000 revisions, through 2006-10-24T18:21:40Z
# Loaded 4500 revisions, through 2006-05-19T09:51:48Z
# Loaded 5000 revisions, through 2006-01-05T16:39:25Z
# Loaded 5500 revisions, through 2005-03-23T19:01:34Z
# Loaded 5819 revisions, through 2001-10-29T16:35:52Z
# Grabbed page at 870702609
# Grabbed page at 817473860
# Grabbed page at 756103692
# Grabbed page at 697631364
# Grabbed page at 639808145
# Grabbed page at 587554838
# Grabbed page at 529596511
# Grabbed page at 467073300
# Grabbed page at 405059826
# Grabbed page at 334256669
# Grabbed page at 260467689
# Grabbed page at 181035213
# Grabbed page at 97252561
# Grabbed page at 33183701
# Grabbed page at 9024886
# Grabbed page at 2181054
# Grabbed page at 595548
# Grabbed page at 273070
# Loaded 1000 revisions, through 2014-10-30T16:00:43Z
# Loaded 1500 revisions, through 2010-09-06T06:43:47Z
# Loaded 2000 revisions, through 2009-08-02T16:10:47Z
# Loaded 2500 revisions, through 2008-10-10T20:58:07Z
# Loaded 3000 revisions, through 2008-05-13T10:12:36Z
# Loaded 3500 revisions, through 2008-03-02T23:37:21Z
# Loaded 4000 revisions, through 2007-11-10T03:05:49Z
# Loaded 4500 revisions, through 2007-09-12T11:59:40Z
# Loaded 5000 revisions, through 2007-05-15T14:30:56Z
# Loaded 5500 revisions, through 2007-02-17T07:13:36Z
# Loaded 6000 revisions, through 2006-12-19T20:31:28Z
# Loaded 6500 revisions, through 2006-10-24T19:04:33Z
# Loaded 7000 revisions, through 2006-08-29T07:42:08Z
# Loaded 7500 revisions, through 2006-03-13T08:12:56Z
# Loaded 8000 revisions, through 2005-11-08T17:42:41Z
# Loaded 8500 revisions, through 2005-02-10T18:08:15Z
# Loaded 8858 revisions, through 2001-11-11T04:17:14Z
# Grabbed page at 870859494
# Grabbed page at 817610783
# Grabbed page at 757042074
# Grabbed page at 696893726
# Grabbed page at 640389001
# Grabbed page at 588121572
# Grabbed page at 530317606
# Grabbed page at 467518280
# Grabbed page at 404504704
# Grabbed page at 334626040
# Grabbed page at 260961348
# Grabbed page at 181111955
# Grabbed page at 97584921
# Grabbed page at 33270633
# Grabbed page at 9061972
# Grabbed page at 2115428
# Grabbed page at 553765
# Grabbed page at 233533
# Loaded 1000 revisions, through 2016-09-02T20:59:53Z
# Loaded 1364 revisions, through 2010-12-30T02:17:55Z
# Grabbed page at 871120577
# Grabbed page at 817243436
# Grabbed page at 757157802
# Grabbed page at 696638555
# Grabbed page at 432735895
# Grabbed page at 404921267

# %%
z = wiki.get_wiki_json("Plato")
