# %% [markdown]
# ## Tutorial 10: Looping through Wikipedia
#
# In this tutorial, we combine our lists and loops with the MediaWiki API
# functions to grab data from several websites in an automated way.

# %% [markdown]
# ### Modules
#
# We will need functions that I gave last class for loading data from
# Wikipedia again today, as well as for the foreseeable future. Rather
# than having to copy and paste them each time, there is an easy way to
# load these functions from a common file.
#
# I've created the file `wiki.py` that you should download from the course
# website and put into the same directory that you store your tutorials.
# You can open and edit the file in Jupyter, which I suggest you do right
# now to get a sense of what the file looks like. It is basically one long
# code cell. To load the functions in this file, we write `import` along
# with the name of the file (without the extension).

# %%
import wiki

# %% [markdown]
# Now, to get one of the functions in the module, we use the normal
# "module name" + "." + "function name" calling convention. So, to
# get the function `wiki_json_path` we would do this:

# %%
wiki.wiki_json_path("University of Richmond")
# Out:
# '/Users/taylor/gh/stat289-f18/assets/data/en/University_of_Richmond.json'

# %% [markdown]
# Remember that you can see the help page for a function like this:

# %%
help(wiki.wiki_json_path)
# Out:
# Help on function wiki_json_path in module wiki:
#
# wiki_json_path(page_title, lang='en')
#     Returns local path to JSON file for Wikipedia page data.
#
#     This function is used to determine where the dump of a
#     call to the MediaWiki API, using the parse method, should
#     be stored. As an extra action, the function also checks that
#     the relevant directory exists and creates it if it does not.
#
#     Args:
#         page_title: A string containing the page title.
#         lang: Two letter language code describing the Wikipedia
#             language used to grab the data.
#
#     Returns:
#         A string describing a relative path to file.

# %% [markdown]
# I've made a few small changes to the code in `wiki.py` to make it function a bit
# better for us and to deal with some annoying edge cases. I may need to fix some
# other edge cases as we work through the data (pages like "AC/DC" and "Guns & Roses"
# failed on the original code).

# %% [markdown]
# ### Dictionaries
#
# We saw last time that internal links, links to other pages on
# Wikipedia, are returned as a particular element of the JSON data
# returned by the MediaWiki API. Here, we will show how to extract
# data from the JSON object.
#
# Let's start by loading the data from a single Wikipedia page. As
# I mentioned briefly last time, the Python object that stores JSON
# data is called a "dict" (short for dictionary).

# %%
data = wiki.get_wiki_json("University of Richmond")
type(data)
# Out:
# Pulling data from MediaWiki API: 'University of Richmond'
# dict

# %% [markdown]
# A dictionary is similar to a list in that it stores an collection of items. While
# a list keeps all of the items in a particular order, a dictionary associated each
# element to a named "key". We saw these keys in the JSON file from last time. To
# see all of the keys in a particular dictionary, use the `keys` method:

# %%
data.keys()
# Out:
# dict_keys(['title', 'pageid', 'revid', 'text', 'langlinks', 'categories', 'links', 'templates', 'images', 'externallinks', 'sections', 'parsewarnings', 'displaytitle', 'iwlinks', 'properties'])

# %% [markdown]
# To grab an element from the dictionary, we use square brackets with the name
# (in quotes) of the desired key. Again, similar to a list but with a twist.
# Here I'll print out the title of the page.

# %%
data['title']
# Out:
# 'University of Richmond'

# %% [markdown]
# The title returns a single string, but its possible that dictionarie elements consists of a
# list or even another dictionary.

# %%
type(data['langlinks'])
# Out:
# list

# %%
data['langlinks']
# Out:
# [{'lang': 'az',
#   'url': 'https://az.wikipedia.org/wiki/Ri%C3%A7mond_Universiteti',
#   'langname': 'Azerbaijani',
#   'autonym': 'azərbaycanca',
#   '*': 'Riçmond Universiteti'},
#  {'lang': 'de',
#   'url': 'https://de.wikipedia.org/wiki/University_of_Richmond',
#   'langname': 'German',
#   'autonym': 'Deutsch',
#   '*': 'University of Richmond'},
#  {'lang': 'es',
#   'url': 'https://es.wikipedia.org/wiki/Universidad_de_Richmond',
#   'langname': 'Spanish',
#   'autonym': 'español',
#   '*': 'Universidad de Richmond'},
#  {'lang': 'it',
#   'url': 'https://it.wikipedia.org/wiki/Universit%C3%A0_di_Richmond',
#   'langname': 'Italian',
#   'autonym': 'italiano',
#   '*': 'Università di Richmond'},
#  {'lang': 'fi',
#   'url': 'https://fi.wikipedia.org/wiki/Richmondin_yliopisto',
#   'langname': 'Finnish',
#   'autonym': 'suomi',
#   '*': 'Richmondin yliopisto'},
#  {'lang': 'sv',
#   'url': 'https://sv.wikipedia.org/wiki/University_of_Richmond',
#   'langname': 'Swedish',
#   'autonym': 'svenska',
#   '*': 'University of Richmond'},
#  {'lang': 'ur',
#   'url': 'https://ur.wikipedia.org/wiki/%DB%8C%D9%88%D9%86%DB%8C%D9%88%D8%B1%D8%B3%D9%B9%DB%8C_%D8%A2%D9%81_%D8%B1%DA%86%D9%85%D9%86%DA%88',
#   'langname': 'Urdu',
#   'autonym': 'اردو',
#   '*': 'یونیورسٹی آف رچمنڈ'},
#  {'lang': 'zh',
#   'url': 'https://zh.wikipedia.org/wiki/%E9%87%8C%E5%A3%AB%E6%BB%A1%E5%A4%A7%E5%AD%A6',
#   'langname': 'Chinese',
#   'autonym': '中文',
#   '*': '里士满大学'}]

# %% [markdown]
# What if we want information about the Azerbaijani page for the University of Richmond?
# Well, this is just a list so grab the first element with `[0]` as usual:

# %%
data['langlinks'][0]
# Out:
# {'lang': 'az',
#  'url': 'https://az.wikipedia.org/wiki/Ri%C3%A7mond_Universiteti',
#  'langname': 'Azerbaijani',
#  'autonym': 'azərbaycanca',
#  '*': 'Riçmond Universiteti'}

# %% [markdown]
# And from what data type is this element? Its another dictionary:

# %%
type(data['langlinks'][0])
# Out:
# dict

# %% [markdown]
# And so we could grab an element, such as the language name, like this:

# %%
data['langlinks'][0]['langname']
# Out:
# 'Azerbaijani'

# %% [markdown]
# And if we want all of the language links? We need to combine our looping
# knowledge with the dictionary methods:

# %%
lang_names = []

for lang in data['langlinks']:
    lang_names = lang_names + [lang['langname']]
    
print(lang_names)
# Out:
# ['Azerbaijani', 'German', 'Spanish', 'Italian', 'Finnish', 'Swedish', 'Urdu', 'Chinese']

# %% [markdown]
# ### Links data
#
# Now, let's do something similar to get the internal links from our Wikipedia page. These
# are stored in the element named 'links' from the object `data`. Print out this object
# below:

# %% [markdown]
# Now, what kind of object are the links stored in? Use the `type` function below to
# figure this out:

# %% [markdown]
# You should see that the links are stored as a list. Each element of the list
# is a particular link. Below, grab just the first (remember, this is element '0')
# link in the list:

# %% [markdown]
# Use the `type` function again to detect the object type of a particular
# link.

# %% [markdown]
# You should see that this is a dictionary. Now (yes, there's more!) print out the names
# of the keys for this dictionary:

# %% [markdown]
# You should see that there are three elements in the dictionary. Here are what
# the three elements mean:
#
# - **ns**: an integer giving the "namespace" of the link. Each type of page has
# its own namespace. The links to "real" pages all have a code of '14'.
# - **exists**: this is an empty string. Its used because the element exists only
# 'exists' if the link is not dead (in other words, it links to a real page).
# - **`*`**: this is the actual internal link.
#
# Print out the namespace of the first link:

# %% [markdown]
# You should see that the namespace is 14 because the first link is to a Category
# page (Categories are always 14).
#
# Now, do something similar to what I did in the prior section to create a list named
# `internal_links` that grabs all of the links (the elements under `*`). Print out
# the list at the bottom of the cell.

# %% [markdown]
# ### Using `links_as_list`
#
# I wrote a small helper funtion `links_as_list` (defined in `wiki.py`) to
# extract the list of links from a webpage. It should work very similar to
# the code you wrote above (open the code file and check it!), but additionally
# only includes links is (1) the namespace is equal to 10 and (2) the page
# actually exists.
#
# Let's use this to get all of the links of the University of Richmond page.

# %%
data = wiki.get_wiki_json("University of Richmond")
links = wiki.links_as_list(data)
links
# Out:
# ['2008 Montana Grizzlies football team',
#  '2008 Richmond Spiders football team',
#  "2010-11 Richmond Spiders men's basketball team",
#  "2010–11 Kansas Jayhawks men's basketball team",
#  "2011 Atlantic 10 Men's Basketball Tournament",
#  "2011 NCAA Men's Division I Basketball Tournament",
#  'A cappella',
#  'Afroman',
#  'Alcoa',
#  'Alpha Kappa Alpha',
#  'Alpha Phi Alpha',
#  'Alpha Phi Omega',
#  'Altria Group',
#  'Aluminum',
#  'Alumnus',
#  'American Civil War',
#  'American Jobs Act',
#  'Appalachian College of Pharmacy',
#  'Appalachian School of Law',
#  'Associated Colleges of the South',
#  'Athletic nickname',
#  'Atlantic 10 Conference',
#  'Atlantic University',
#  'Auburn University',
#  'Averett University',
#  'Baptist Theological Seminary at Richmond',
#  'Baptists',
#  'Barracks',
#  'Baylor University',
#  'Bill Clinton',
#  'Birmingham–Southern College',
#  'Blackstone College for Girls',
#  'Bluefield College',
#  'Bon Secours Memorial College of Nursing',
#  'Bonner Scholars',
#  'Bridgewater College',
#  'BusinessWeek',
#  'Capital City Classic',
#  'Capital Cup',
#  'Catholic University of America',
#  'Centenary College of Louisiana',
#  'Centre College',
#  'Chancellor (education)',
#  'Charles Gillette',
#  'Christendom College',
#  'Christopher Newport University',
#  'Clemson University',
#  'College',
#  'College football',
#  'College of William & Mary',
#  'Collegiate gothic',
#  'Columbia (Richmond, Virginia)',
#  'Commander in Chief (television)',
#  'Confederate States of America',
#  'Cordoba University',
#  'Cornell University',
#  'Council of Independent Colleges',
#  'Cry Wolf (2005 film)',
#  'Davidson College',
#  'Davidson Wildcats',
#  "Dawson's Creek",
#  'Dayton Flyers',
#  'DeVry University',
#  'Delta Delta Delta',
#  'Delta Gamma',
#  'Delta Sigma Theta',
#  'Duke University',
#  'Duquesne Dukes',
#  'E. Bruce Heilman',
#  'E. Claiborne Robins School of Business',
#  'E. Claiborne Robins Sr',
#  'E. Claiborne Robins Stadium',
#  'ECPI University',
#  'East Carolina University',
#  'Eastern Mennonite University',
#  'Eastern Virginia Medical School',
#  'Edward Via College of Osteopathic Medicine',
#  'Eighth blackbird',
#  'Elizabeth College (Virginia)',
#  'Emory and Henry College',
#  'Ferrum College',
#  'Financial endowment',
#  'Flo Rida',
#  'Florida Atlantic University',
#  'Florida Institute of Technology',
#  'Florida International University',
#  'Florida State University',
#  'Fordham Rams',
#  'Frederic W. Boatwright',
#  'Frederick College',
#  'Frederick Law Olmsted',
#  'Furman University',
#  'Geena Davis',
#  'Geographic coordinate system',
#  'George H. W. Bush',
#  'George Mason Patriots',
#  'George Mason University',
#  'George Washington Colonials',
#  'George Washington University',
#  'George Washington University Virginia Science & Technology Campus',
#  'Georgetown University',
#  'Georgia Institute of Technology',
#  'Georgia State University',
#  'Gibbs College',
#  'Goochland County, Virginia',
#  'Gordon Bunshaft',
#  'Gottwald Center for the Sciences',
#  "Governor's Schools (Virginia)",
#  'H. Gerald Quigg',
#  'Habitat for Humanity',
#  'Hampden–Sydney College',
#  'Hampton University',
#  'Hartland Institute',
#  'Hendrix College',
#  'Henrico County, Virginia',
#  'Henry Mansfield Cannon Memorial Chapel',
#  'Hollins University',
#  'Honor code',
#  'Idaho State University',
#  'International Standard Book Number',
#  'James Madison University',
#  'Jefferson College of Health Sciences',
#  'Jefferson Hotel (Richmond, Virginia)',
#  'Jepson School of Leadership Studies',
#  'John Leland Center for Theological Studies',
#  'Joint Forces Staff College',
#  'Kappa Alpha Order',
#  'Kappa Alpha Theta',
#  'Kappa Delta',
#  'Kappa Kappa Gamma',
#  'La Salle Explorers',
#  'Lambda Chi Alpha',
#  'Latin',
#  'Leadership Studies',
#  'Liberal arts',
#  'Liberty University',
#  'List of University of Richmond people',
#  'List of colleges and universities in Virginia',
#  'Longwood University',
#  'Louisiana State University',
#  'Louisiana Tech University',
#  'Mackenzie Allen',
#  'Malcolm U. Pitt Field',
#  'Marine Corps University',
#  'Marion College, Virginia',
#  'Mary Baldwin University',
#  'Marymount University',
#  'Massachusetts Institute of Technology',
#  'Mid-Atlantic States',
#  'Millsaps College',
#  'Mississippi State University',
#  'Model United Nations',
#  'Morehouse College',
#  'NCAA Division I',
#  'NCAA Division I Football Championship',
#  'National Public Radio',
#  'National Register of Historic Places',
#  'National Science Foundation',
#  'Need-blind admission',
#  'New England',
#  'Nonsectarian',
#  'Norfolk State University',
#  'North Carolina A&T State University',
#  'North Carolina State University',
#  'North Court',
#  'Ohio University',
#  'Old Dominion University',
#  'Patrick Henry College',
#  'Phi Beta Kappa',
#  'Phi Gamma Delta',
#  'Philip Morris USA',
#  'Pi Beta Phi',
#  'Postgraduate education',
#  'President Obama',
#  'President of the University of Richmond',
#  'Princeton University',
#  'Private school',
#  'Private university',
#  'Radford University',
#  'Ralph Adams Cram',
#  'Randolph College',
#  'Randolph–Macon College',
#  'Regent University',
#  'Reynolds Metals Company International Headquarters',
#  'Rhode Island Rams',
#  'Rhodes College',
#  'Rice University',
#  'Richard Bland College',
#  'Richmond, Virginia',
#  'Richmond Spiders',
#  'Richmond Spiders baseball',
#  'Richmond Spiders football',
#  "Richmond Spiders men's basketball",
#  "Richmond Spiders men's lacrosse",
#  "Richmond Spiders women's basketball",
#  'Roanoke College',
#  'Robins Center',
#  'Rollins College',
#  'Ronald Crutcher',
#  'Ross Perot',
#  'Ryland Hall (Richmond, Virginia)',
#  "Saint Joseph's Hawks",
#  'Saint Louis Billikens',
#  "Saint Paul's College (Virginia)",
#  'School colors',
#  'Sewanee: The University of the South',
#  'Shanghai Quartet',
#  'Shenandoah University',
#  'Sigma Chi',
#  'Sigma Phi Epsilon',
#  'SmartMoney',
#  'Southeastern Universities Research Association',
#  'Southern Virginia University',
#  'Southwestern University',
#  'Spelman College',
#  'Spider',
#  'St. Bonaventure Bonnies',
#  'Stratford University',
#  'Student financial aid (United States)',
#  'Study abroad',
#  'Suburban',
#  'Sullins College',
#  'Sweet Briar College',
#  'Texas A&M University',
#  'The Art Institute of Washington',
#  'The Art Institutes',
#  'The Collegian (University of Richmond)',
#  'The Princeton Review',
#  'The West End (Richmond, Virginia)',
#  'Theta Chi',
#  'Trinity University (Texas)',
#  'Trustee',
#  'Tulane University',
#  'U.S. News and World Report',
#  'UMass Minutemen and Minutewomen',
#  'Undergraduate education',
#  'Union (American Civil War)',
#  'Union Presbyterian Seminary',
#  'University of Alabama',
#  'University of Alabama at Birmingham',
#  'University of Alabama in Huntsville',
#  'University of Arkansas',
#  'University of Central Florida',
#  'University of Delaware',
#  'University of Florida',
#  'University of Georgia',
#  'University of Houston',
#  'University of Kentucky',
#  'University of Louisiana at Lafayette',
#  'University of Lynchburg',
#  'University of Management and Technology (United States)',
#  'University of Mary Washington',
#  'University of Maryland, Baltimore County',
#  'University of Maryland, College Park',
#  'University of Massachusetts Amherst',
#  'University of Memphis',
#  'University of Miami',
#  'University of Mississippi',
#  'University of New Orleans',
#  'University of North Carolina at Chapel Hill',
#  'University of Northern Virginia',
#  'University of Oklahoma',
#  'University of Regina',
#  'University of Richmond School of Law',
#  'University of Richmond School of Professional & Continuing Studies',
#  'University of South Carolina',
#  'University of South Florida',
#  'University of Southern Mississippi',
#  'University of Tennessee',
#  'University of Texas at Austin',
#  'University of Virginia',
#  "University of Virginia's College at Wise",
#  'University of the Potomac',
#  'University president',
#  'V-12 Navy College Training Program',
#  'VCU Rams',
#  'Vanderbilt University',
#  'Vice President of the United States',
#  'Virginia',
#  'Virginia Commonwealth University',
#  'Virginia Community College System',
#  'Virginia Intermont College',
#  'Virginia International University',
#  'Virginia Military Institute',
#  'Virginia State University',
#  'Virginia Tech',
#  'Virginia Theological Seminary',
#  'Virginia Union University',
#  'Virginia University of Lynchburg',
#  'Virginia Wesleyan University',
#  'Virginia–Maryland College of Veterinary Medicine',
#  'WDCE',
#  'Warren H. Manning',
#  'Warren Manning',
#  'Washington and Lee University',
#  'West Virginia University',
#  'Westwood College',
#  'Williams College',
#  'World War II']

# %% [markdown]
# Now, a reasonable next step would be to grab the data associated with
# each of these pages. To download the data for the first link we would
# just do this:

# %%
data = wiki.get_wiki_json(links[0])
data
# Out:
# Pulling data from MediaWiki API: '2008 Montana Grizzlies football team'
# {'title': '2008 Montana Grizzlies football team',
#  'pageid': 23897286,
#  'revid': 841752145,
#  'text': {'*': '<div class="mw-parser-output"><table class="infobox vevent" style="width:22em;width: 25em"><tbody><tr><th colspan="2" class="summary" style="text-align:center;font-size:125%;font-weight:bold;font-size: 125%"><span class="dtstart">2008</span> <span class="vcard attendee fn org"><a href="/wiki/Montana_Grizzlies_football" title="Montana Grizzlies football">Montana Grizzlies football</a></span></th></tr><tr><td colspan="2" style="text-align:center">\n<a href="/wiki/File:Montana_Griz_logo.svg" class="image"><img alt="Montana Griz logo.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3b/Montana_Griz_logo.svg/150px-Montana_Griz_logo.svg.png" width="150" height="109" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3b/Montana_Griz_logo.svg/225px-Montana_Griz_logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3b/Montana_Griz_logo.svg/300px-Montana_Griz_logo.svg.png 2x" data-file-width="133" data-file-height="97" /></a></td></tr><tr><th colspan="2" style="text-align:center"><div style="width:100%;background-color: #fb0">Big Sky co-champion</div></th></tr><tr><th colspan="2" style="text-align:center"><div style="width:100%;background-color: #fb0">Division I FCS National Championship Final, L 7–24 vs. <a href="/wiki/2008_Richmond_Spiders_football_team" title="2008 Richmond Spiders football team">Richmond</a></div></th></tr><tr><th scope="row">Conference</th><td>\n<a href="/wiki/Big_Sky_Conference" title="Big Sky Conference">Big Sky Conference</a></td></tr><tr><th scope="row">2008 record</th><td>\n14–2 (7–1 Big Sky)</td></tr><tr><th scope="row">Head&#160;coach</th><td>\n<a href="/wiki/Bobby_Hauck" title="Bobby Hauck">Bobby Hauck</a> (6th season)</td></tr><tr><th scope="row">Offensive&#160;coordinator</th><td>\nRob Phenicie (6th season)</td></tr><tr><th scope="row">Defensive&#160;coordinator</th><td>\nKraig Paulson (5th season)</td></tr><tr><th scope="row">Home&#160;stadium</th><td>\n<a href="/wiki/Washington%E2%80%93Grizzly_Stadium" title="Washington–Grizzly Stadium">Washington–Grizzly Stadium</a> (Capacity: 25,217)</td></tr><tr><td colspan="2" class="noprint" style="text-align:center;background:#eee;">\n<div class="" style="width:100%; text-align:center;">Seasons</div><div style="width:100%"><div style="float: left; text-align:left;padding-right:0.5em;" class="noprint">&#8592;&#160;<a href="/wiki/2007_Montana_Grizzlies_football_team" title="2007 Montana Grizzlies football team">2007</a></div><div style="float: right; text-align:right;padding-left:0.5em;" class="noprint"><a href="/wiki/2009_Montana_Grizzlies_football_team" title="2009 Montana Grizzlies football team">2009</a>&#160;&#8594;</div></div></td></tr></tbody></table>\n<table class="infobox" style="width:25em; text-align:center; font-size:88%; line-height: 1.5em;">\n\n<tbody><tr>\n<th colspan="99" style="text-align:center;background:#eee; white-space:normal;">2008 Big Sky football standings\n</th></tr>\n<tr>\n<th style="text-align:left;" width="50%"><div class="plainlinks hlist navbar mini"><ul><li class="nv-view"><a href="/wiki/Template:2008_Big_Sky_football_standings" title="Template:2008 Big Sky football standings"><abbr title="View this template">v</abbr></a></li><li class="nv-talk"><a href="/wiki/Template_talk:2008_Big_Sky_football_standings" title="Template talk:2008 Big Sky football standings"><abbr title="Discuss this template">t</abbr></a></li><li class="nv-edit"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Template:2008_Big_Sky_football_standings&amp;action=edit"><abbr title="Edit this template">e</abbr></a></li></ul></div></th>\n<th colspan="5" style="width:1%;text-align:center;"><abbr title="Conference record">Conf</abbr></th>\n<th>&#160;</th>\n<th>&#160;</th>\n<th colspan="5" style="width:1%;text-align:center;">Overall\n</th></tr>\n<tr>\n<th style="text-align:left;"><u>Team</u></th>\n<th>&#160;</th>\n<th><u><abbr title="Wins">W</abbr></u></th>\n<th>&#160;</th>\n<th><u><abbr title="Losses">L</abbr ...
#  'langlinks': [],
#  'categories': [{'sortkey': '',
#    'hidden': '',
#    '*': 'NCAA_team_season_with_no_sport_parameter'},
#   {'sortkey': 'Montana Grizzlies',
#    '*': '2008_Big_Sky_Conference_football_season'},
#   {'sortkey': '', '*': 'Montana_Grizzlies_football_seasons'},
#   {'sortkey': '', '*': 'Big_Sky_Conference_football_champion_seasons'},
#   {'sortkey': 'Montana Grizzlies f', '*': '2008_in_sports_in_Montana'}],
#  'links': [{'ns': 0,
#    'exists': '',
#    '*': '2007 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2009 Montana Grizzlies football team'},
#   {'ns': 0, '*': '2008 Weber State Wildcats football team'},
#   {'ns': 0, 'exists': '', '*': 'Weber State Wildcats football'},
#   {'ns': 0, '*': '2008 Eastern Washington Eagles football team'},
#   {'ns': 0, 'exists': '', '*': 'Eastern Washington Eagles football'},
#   {'ns': 0, '*': '2008 Northern Arizona Lumberjacks football team'},
#   {'ns': 0, 'exists': '', '*': 'Northern Arizona Lumberjacks football'},
#   {'ns': 0, '*': '2008 Northern Colorado Bears football team'},
#   {'ns': 0, 'exists': '', '*': 'Northern Colorado Bears football'},
#   {'ns': 0, '*': '2008 Idaho State Bengals football team'},
#   {'ns': 0, 'exists': '', '*': 'Idaho State Bengals football'},
#   {'ns': 0, '*': '2008 Southern Utah Thunderbirds football team'},
#   {'ns': 0, 'exists': '', '*': 'Southern Utah Thunderbirds football'},
#   {'ns': 0, '*': '2008 Central Washington Wildcats football team'},
#   {'ns': 0, 'exists': '', '*': 'Central Washington Wildcats football'},
#   {'ns': 0, '*': '2008 Texas State Bobcats football team'},
#   {'ns': 0, 'exists': '', '*': 'Texas State Bobcats football'},
#   {'ns': 0, '*': '1963 Idaho State Bengals football team'},
#   {'ns': 0, '*': '1964 Montana State Bobcats football team'},
#   {'ns': 0, 'exists': '', '*': 'Montana State Bobcats football'},
#   {'ns': 0, '*': '1965 Weber State Wildcats football team'},
#   {'ns': 0, '*': '1966 Montana State Bobcats football team'},
#   {'ns': 0, '*': '1967 Montana State Bobcats football team'},
#   {'ns': 0, '*': '1968 Montana State Bobcats football team'},
#   {'ns': 0, '*': '1968 Weber State Wildcats football team'},
#   {'ns': 0, '*': '1972 Montana State Bobcats football team'},
#   {'ns': 0, '*': '1978 Northern Arizona Lumberjacks football team'},
#   {'ns': 0, '*': '1979 Montana State Bobcats football team'},
#   {'ns': 0, '*': '1982 Montana State Bobcats football team'},
#   {'ns': 0, '*': '1983 Nevada Wolf Pack football team'},
#   {'ns': 0, 'exists': '', '*': 'Nevada Wolf Pack football'},
#   {'ns': 0, '*': '1986 Nevada Wolf Pack football team'},
#   {'ns': 0, '*': '1991 Nevada Wolf Pack football team'},
#   {'ns': 0, '*': '1992 Eastern Washington Eagles football team'},
#   {'ns': 0, '*': '1997 Eastern Washington Eagles football team'},
#   {'ns': 0, '*': '2002 Montana State Bobcats football team'},
#   {'ns': 0, '*': '2002 Idaho State Bengals football team'},
#   {'ns': 0, '*': '2003 Montana State Bobcats football team'},
#   {'ns': 0, '*': '2003 Northern Arizona Lumberjacks football team'},
#   {'ns': 0, '*': '2004 Eastern Washington Eagles football team'},
#   {'ns': 0, '*': '2005 Eastern Washington Eagles football team'},
#   {'ns': 0, '*': '2005 Montana State Bobcats football team'},
#   {'ns': 0, '*': '2008 Colgate Raiders football team'},
#   {'ns': 0, 'exists': '', '*': 'Colgate Raiders football'},
#   {'ns': 0, '*': '2008 Eastern Kentucky Colonels football team'},
#   {'ns': 0, 'exists': '', '*': 'Eastern Kentucky Colonels football'},
#   {'ns': 0, '*': '2008 Maine Black Bears football team'},
#   {'ns': 0, 'exists': '', '*': 'Maine Black Bears football'},
#   {'ns': 0, '*': '2008 South Carolina State Bulldogs football team'},
#   {'ns': 0, 'exists': '', '*': 'South Carolina State Bulldogs football'},
#   {'ns': 0, '*': '2008 Southern Illinois Salukis football team'},
#   {'ns': 0, 'exists': '', '*': 'Southern Illinois Salukis football'},
#   {'ns': 0, '*': '2008 Villanova Wildcats football team'},
#   {'ns': 0, 'exists': '', '*': 'Villanova Wildcats football'},
#   {'ns': 0, '*': '2008 Wofford Terriers football team'},
#   {'ns': 0, 'exists': '', '*': 'Wofford Terriers football'},
#   {'ns': 0, 'exists': '', '*': '1897 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1898 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1899 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1900 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1901 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1902 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1903 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1904 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1905 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1906 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1907 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1908 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1909 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1910 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1911 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1912 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1913 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1914 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1915 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1916 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1917 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1919 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1920 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1921 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1922 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1923 Montana football team'},
#   {'ns': 0, 'exists': '', '*': '1924 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1925 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1926 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1927 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1928 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1929 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1930 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1931 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1932 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1933 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1934 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1935 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1936 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1937 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1938 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1939 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1940 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1941 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1942 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1943 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1944 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1945 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1946 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1947 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1948 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1949 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1950 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1951 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1952 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1953 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1954 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1955 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1956 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1957 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1958 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1959 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1960 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1961 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1962 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1963 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1964 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1965 Idaho Vandals football team'},
#   {'ns': 0, 'exists': '', '*': '1965 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1966 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1967 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1968 Idaho Vandals football team'},
#   {'ns': 0, 'exists': '', '*': '1968 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1969 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1970 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1971 Idaho Vandals football team'},
#   {'ns': 0, 'exists': '', '*': '1971 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1972 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1973 Boise State Broncos football team'},
#   {'ns': 0, 'exists': '', '*': '1973 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1974 Boise State Broncos football team'},
#   {'ns': 0, 'exists': '', '*': '1974 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1975 Boise State Broncos football team'},
#   {'ns': 0, 'exists': '', '*': '1975 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1976 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1976 Montana State Bobcats football team'},
#   {'ns': 0, 'exists': '', '*': '1977 Boise State Broncos football team'},
#   {'ns': 0, 'exists': '', '*': '1977 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1978 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1979 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1980 Boise State Broncos football team'},
#   {'ns': 0, 'exists': '', '*': '1980 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1981 Idaho State Bengals football team'},
#   {'ns': 0, 'exists': '', '*': '1981 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1982 Idaho Vandals football team'},
#   {'ns': 0, 'exists': '', '*': '1982 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1983 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1984 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1984 Montana State Bobcats football team'},
#   {'ns': 0, 'exists': '', '*': '1985 Idaho Vandals football team'},
#   {'ns': 0, 'exists': '', '*': '1985 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1986 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1987 Idaho Vandals football team'},
#   {'ns': 0, 'exists': '', '*': '1987 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1988 Idaho Vandals football team'},
#   {'ns': 0, 'exists': '', '*': '1988 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1989 Idaho Vandals football team'},
#   {'ns': 0, 'exists': '', '*': '1989 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1990 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1990 Nevada Wolf Pack football team'},
#   {'ns': 0, 'exists': '', '*': '1991 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1992 Idaho Vandals football team'},
#   {'ns': 0, 'exists': '', '*': '1992 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1993 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1994 Boise State Broncos football team'},
#   {'ns': 0, 'exists': '', '*': '1994 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1995 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1996 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1997 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1998 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '1999 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2000 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2001 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2002 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2003 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2004 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2005 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2006 Montana Grizzlies football team'},
#   {'ns': 0,
#    'exists': '',
#    '*': '2008 Appalachian State Mountaineers football team'},
#   {'ns': 0, 'exists': '', '*': '2008 Cal Poly Mustangs football team'},
#   {'ns': 0, 'exists': '', '*': '2008 James Madison Dukes football team'},
#   {'ns': 0, 'exists': '', '*': '2008 Montana State Bobcats football team'},
#   {'ns': 0, 'exists': '', '*': '2008 NCAA Division I FBS football rankings'},
#   {'ns': 0, 'exists': '', '*': '2008 NCAA Division I FCS football season'},
#   {'ns': 0, 'exists': '', '*': '2008 New Hampshire Wildcats football team'},
#   {'ns': 0, 'exists': '', '*': '2008 Northern Iowa Panthers football team'},
#   {'ns': 0, 'exists': '', '*': '2008 Portland State Vikings football team'},
#   {'ns': 0, 'exists': '', '*': '2008 Richmond Spiders football team'},
#   {'ns': 0, 'exists': '', '*': '2008 Sacramento State Hornets football team'},
#   {'ns': 0, 'exists': '', '*': '2008 UC Davis Aggies football team'},
#   {'ns': 0, 'exists': '', '*': '2010 Eastern Washington Eagles football team'},
#   {'ns': 0, 'exists': '', '*': '2010 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2010 Montana State Bobcats football team'},
#   {'ns': 0, 'exists': '', '*': '2011 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2011 Montana State Bobcats football team'},
#   {'ns': 0, 'exists': '', '*': '2012 Cal Poly Mustangs football team'},
#   {'ns': 0, 'exists': '', '*': '2012 Eastern Washington Eagles football team'},
#   {'ns': 0, 'exists': '', '*': '2012 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2012 Montana State Bobcats football team'},
#   {'ns': 0, 'exists': '', '*': '2013 Eastern Washington Eagles football team'},
#   {'ns': 0, 'exists': '', '*': '2013 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2014 Eastern Washington Eagles football team'},
#   {'ns': 0, 'exists': '', '*': '2014 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': '2015 Montana Grizzlies football team'},
#   {'ns': 0,
#    'exists': '',
#    '*': '2015 Southern Utah Thunderbirds football team'},
#   {'ns': 0, 'exists': '', '*': '2016 Eastern Washington Eagles football team'},
#   {'ns': 0, 'exists': '', '*': '2016 Montana Grizzlies football team'},
#   {'ns': 0,
#    'exists': '',
#    '*': '2016 North Dakota Fighting Hawks football team'},
#   {'ns': 0, 'exists': '', '*': '2017 Montana Grizzlies football team'},
#   {'ns': 0,
#    'exists': '',
#    '*': '2017 Southern Utah Thunderbirds football team'},
#   {'ns': 0, 'exists': '', '*': '2017 Weber State Wildcats football team'},
#   {'ns': 0, 'exists': '', '*': '2018 Montana Grizzlies football team'},
#   {'ns': 0, 'exists': '', '*': 'Alex G. Spanos Stadium'},
#   {'ns': 0, 'exists': '', '*': 'Big Sky Conference'},
#   {'ns': 0, 'exists': '', '*': 'Bobby Hauck'},
#   {'ns': 0, 'exists': '', '*': 'Brawl of the Wild'},
#   {'ns': 0, 'exists': '', '*': 'Bridgeforth Stadium and Zane Showker Field'},
#   {'ns': 0, 'exists': '', '*': 'Butte, Montana'},
#   {'ns': 0, 'exists': '', '*': 'Chattanooga, Tennessee'},
#   {'ns': 0, 'exists': '', '*': 'Cheney, Washington'},
#   {'ns': 0, 'exists': '', '*': 'Dornblaser Field'},
#   {'ns': 0, 'exists': '', '*': 'ESPN College Football'},
#   {'ns': 0, 'exists': '', '*': 'ESPN GamePlan'},
#   {'ns': 0, 'exists': '', '*': 'EWU–UM Governors Cup'},
#   {'ns': 0, 'exists': '', '*': 'Finley Stadium'},
#   {'ns': 0, 'exists': '', '*': 'Greeley, Colorado'},
#   {'ns': 0, 'exists': '', '*': 'Harrisonburg, Virginia'},
#   {'ns': 0, 'exists': '', '*': 'KPAX-TV'},
#   {'ns': 0, 'exists': '', '*': 'List of Montana Grizzlies football seasons'},
#   {'ns': 0,
#    'exists': '',
#    '*': 'List of Montana Grizzlies head football coaches'},
#   {'ns': 0, 'exists': '', '*': 'List of Montana Grizzlies in the NFL Draft'},
#   {'ns': 0, 'exists': '', '*': 'Little Brown Stein'},
#   {'ns': 0, 'exists': '', '*': 'Missoula, Montana'},
#   {'ns': 0, 'exists': '', '*': 'Montana Grizzlies football'},
#   {'ns': 0, 'exists': '', '*': 'Montana–Montana State football rivalry'},
#   {'ns': 0, 'exists': '', '*': 'Monte (mascot)'},
#   {'ns': 0, 'exists': '', '*': 'Mountain Time Zone'},
#   {'ns': 0, 'exists': '', '*': 'NCAA Division I Football Championship'},
#   {'ns': 0, 'exists': '', '*': 'Nottingham Field'},
#   {'ns': 0, 'exists': '', '*': 'Ogden, Utah'},
#   {'ns': 0, 'exists': '', '*': 'PGE Park'},
#   {'ns': 0, 'exists': '', '*': 'Portland, Oregon'},
#   {'ns': 0, 'exists': '', '*': 'San Luis Obispo, California'},
#   {'ns': 0, 'exists': '', '*': 'Stewart Stadium'},
#   {'ns': 0, 'exists': '', '*': 'University of Montana'},
#   {'ns': 0, 'exists': '', '*': 'University of Montana Grizzly Marching Band'},
#   {'ns': 0, 'exists': '', '*': 'Up With Montana'},
#   {'ns': 0, 'exists': '', '*': 'Washington–Grizzly Stadium'},
#   {'ns': 0, 'exists': '', '*': 'Woodward Field (stadium)'},
#   {'ns': 0, '*': 'Naranche Stadium'},
#   {'ns': 10, 'exists': '', '*': 'Template:2008 Big Sky football standings'},
#   {'ns': 10, 'exists': '', '*': 'Template:Montana Grizzlies football navbox'},
#   {'ns': 10,
#    'exists': '',
#    '*': 'Template:Big Sky Conference football champions'},
#   {'ns': 10, 'exists': '', '*': 'Template:2008 Division I FCS playoff navbox'},
#   {'ns': 11,
#    'exists': '',
#    '*': 'Template talk:2008 Big Sky football standings'},
#   {'ns': 11,
#    'exists': '',
#    '*': 'Template talk:2008 Division I FCS playoff navbox'},
#   {'ns': 11,
#    'exists': '',
#    '*': 'Template talk:Big Sky Conference football champions'},
#   {'ns': 11,
#    'exists': '',
#    '*': 'Template talk:Montana Grizzlies football navbox'}],
#  'templates': [{'ns': 10,
#    'exists': '',
#    '*': 'Template:Infobox NCAA team season'},
#   {'ns': 10, 'exists': '', '*': 'Template:Infobox'},
#   {'ns': 10, 'exists': '', '*': 'Template:Infobox NCAA team season/link'},
#   {'ns': 10, 'exists': '', '*': 'Template:Infobox NCAA team season/team'},
#   {'ns': 10, 'exists': '', '*': 'Template:Infobox NCAA team season/name'},
#   {'ns': 10, 'exists': '', '*': 'Template:MultiReplace'},
#   {'ns': 10,
#    'exists': '',
#    '*': 'Template:Infobox NCAA team season/succession'},
#   {'ns': 10, 'exists': '', '*': 'Template:Succession links'},
#   {'ns': 10, 'exists': '', '*': 'Template:Template other'},
#   {'ns': 10, 'exists': '', '*': 'Template:Main other'},
#   {'ns': 10, 'exists': '', '*': 'Template:2008 Big Sky football standings'},
#   {'ns': 10, 'exists': '', '*': 'Template:CFB Standings Start'},
#   {'ns': 10, 'exists': '', '*': 'Template:Standings Table Start'},
#   {'ns': 10, 'exists': '', '*': 'Template:Navbar'},
#   {'ns': 10, 'exists': '', '*': 'Template:Standings Table Start/colspan'},
#   {'ns': 10, 'exists': '', '*': 'Template:Both'},
#   {'ns': 10, 'exists': '', '*': 'Template:Abbr'},
#   {'ns': 10, 'exists': '', '*': 'Template:Standings Table Start/colheader'},
#   {'ns': 10, 'exists': '', '*': 'Template:CFB Standings Entry'},
#   {'ns': 10, 'exists': '', '*': 'Template:Standings Table Entry'},
#   {'ns': 10, 'exists': '', '*': 'Template:!!'},
#   {'ns': 10, 'exists': '', '*': 'Template:Standings Table Entry/record'},
#   {'ns': 10, 'exists': '', '*': 'Template:Cfb link'},
#   {'ns': 10, 'exists': '', '*': 'Template:CFB Standings End'},
#   {'ns': 10, 'exists': '', '*': 'Template:Standings Table End'},
#   {'ns': 10, 'exists': '', '*': 'Template:Unbulleted list'},
#   {'ns': 10, 'exists': '', '*': 'Template:CFB Schedule Start'},
#   {'ns': 10, 'exists': '', '*': 'Template:Cfb division'},
#   {'ns': 10, 'exists': '', '*': 'Template:CFB Schedule Entry'},
#   {'ns': 10, 'exists': '', '*': 'Template:Dagger'},
#   {'ns': 10, 'exists': '', '*': 'Template:If empty'},
#   {'ns': 10, 'exists': '', '*': 'Template:CFB Schedule End'},
#   {'ns': 10, 'exists': '', '*': 'Template:Reflist'},
#   {'ns': 10, 'exists': '', '*': 'Template:Montana Grizzlies football navbox'},
#   {'ns': 10, 'exists': '', '*': 'Template:Navbox'},
#   {'ns': 10, 'exists': '', '*': 'Template:Color'},
#   {'ns': 10, 'exists': '', '*': 'Template:CollegePrimaryStyle'},
#   {'ns': 10,
#    'exists': '',
#    '*': 'Template:Big Sky Conference football champions'},
#   {'ns': 10, 'exists': '', '*': 'Template:2008 Division I FCS playoff navbox'},
#   {'ns': 828, 'exists': '', '*': 'Module:Infobox'},
#   {'ns': 828, 'exists': '', '*': 'Module:Navbar'},
#   {'ns': 828, 'exists': '', '*': 'Module:MultiReplace'},
#   {'ns': 828, 'exists': '', '*': 'Module:InfoboxImage'},
#   {'ns': 828, 'exists': '', '*': 'Module:String'},
#   {'ns': 828, 'exists': '', '*': 'Module:Check for unknown parameters'},
#   {'ns': 828, 'exists': '', '*': 'Module:Arguments'},
#   {'ns': 828, 'exists': '', '*': 'Module:List'},
#   {'ns': 828, 'exists': '', '*': 'Module:TableTools'},
#   {'ns': 828, 'exists': '', '*': 'Module:If empty'},
#   {'ns': 828, 'exists': '', '*': 'Module:Navbox'},
#   {'ns': 828, 'exists': '', '*': 'Module:College color'},
#   {'ns': 828, 'exists': '', '*': 'Module:College color/data'}],
#  'images': ['Montana_Griz_logo.svg', 'Dagger-14-plain.png'],
#  'externallinks': [],
#  'sections': [{'toclevel': 1,
#    'level': '2',
#    'line': 'Schedule',
#    'number': '1',
#    'index': '1',
#    'fromtitle': '2008_Montana_Grizzlies_football_team',
#    'byteoffset': 1501,
#    'anchor': 'Schedule'},
#   {'toclevel': 1,
#    'level': '2',
#    'line': 'References',
#    'number': '2',
#    'index': '2',
#    'fromtitle': '2008_Montana_Grizzlies_football_team',
#    'byteoffset': 9474,
#    'anchor': 'References'}],
#  'parsewarnings': [],
#  'displaytitle': '2008 Montana Grizzlies football team',
#  'iwlinks': [],
#  'properties': [{'name': 'wikibase_item', '*': 'Q4611529'}]}

# %% [markdown]
# How do this automatically for all of the links? We want to make use
# of a `for` loop. A for loop cycles through all of the elements of a
# list and applies a set of instructions to each element.
#
# Here's an example where we take each element in the list of links and
# print out just the first three letters:

# %%
for link in links:
    print(link[:3])
# Out:
# 200
# 200
# 201
# 201
# 201
# 201
# A c
# Afr
# Alc
# Alp
# Alp
# Alp
# Alt
# Alu
# Alu
# Ame
# Ame
# App
# App
# Ass
# Ath
# Atl
# Atl
# Aub
# Ave
# Bap
# Bap
# Bar
# Bay
# Bil
# Bir
# Bla
# Blu
# Bon
# Bon
# Bri
# Bus
# Cap
# Cap
# Cat
# Cen
# Cen
# Cha
# Cha
# Chr
# Chr
# Cle
# Col
# Col
# Col
# Col
# Col
# Com
# Con
# Cor
# Cor
# Cou
# Cry
# Dav
# Dav
# Daw
# Day
# DeV
# Del
# Del
# Del
# Duk
# Duq
# E.
# E.
# E.
# E.
# ECP
# Eas
# Eas
# Eas
# Edw
# Eig
# Eli
# Emo
# Fer
# Fin
# Flo
# Flo
# Flo
# Flo
# Flo
# For
# Fre
# Fre
# Fre
# Fur
# Gee
# Geo
# Geo
# Geo
# Geo
# Geo
# Geo
# Geo
# Geo
# Geo
# Geo
# Gib
# Goo
# Gor
# Got
# Gov
# H.
# Hab
# Ham
# Ham
# Har
# Hen
# Hen
# Hen
# Hol
# Hon
# Ida
# Int
# Jam
# Jef
# Jef
# Jep
# Joh
# Joi
# Kap
# Kap
# Kap
# Kap
# La
# Lam
# Lat
# Lea
# Lib
# Lib
# Lis
# Lis
# Lon
# Lou
# Lou
# Mac
# Mal
# Mar
# Mar
# Mar
# Mar
# Mas
# Mid
# Mil
# Mis
# Mod
# Mor
# NCA
# NCA
# Nat
# Nat
# Nat
# Nee
# New
# Non
# Nor
# Nor
# Nor
# Nor
# Ohi
# Old
# Pat
# Phi
# Phi
# Phi
# Pi
# Pos
# Pre
# Pre
# Pri
# Pri
# Pri
# Rad
# Ral
# Ran
# Ran
# Reg
# Rey
# Rho
# Rho
# Ric
# Ric
# Ric
# Ric
# Ric
# Ric
# Ric
# Ric
# Ric
# Roa
# Rob
# Rol
# Ron
# Ros
# Ryl
# Sai
# Sai
# Sai
# Sch
# Sew
# Sha
# She
# Sig
# Sig
# Sma
# Sou
# Sou
# Sou
# Spe
# Spi
# St.
# Str
# Stu
# Stu
# Sub
# Sul
# Swe
# Tex
# The
# The
# The
# The
# The
# The
# Tri
# Tru
# Tul
# U.S
# UMa
# Und
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# Uni
# V-1
# VCU
# Van
# Vic
# Vir
# Vir
# Vir
# Vir
# Vir
# Vir
# Vir
# Vir
# Vir
# Vir
# Vir
# Vir
# Vir
# WDC
# War
# War
# Was
# Wes
# Wes
# Wil
# Wor

# %% [markdown]
# If we want to grab the webpage data for each link from the UR page,
# we can now just do this (this will take a while the first time you
# run it, but will be quick the second time):

# %%
for link in links:
    wiki.get_wiki_json(link)
# Out:
# Pulling data from MediaWiki API: '2008 Richmond Spiders football team'
# Pulling data from MediaWiki API: '2010-11 Richmond Spiders men's basketball team'
# Pulling data from MediaWiki API: '2010–11 Kansas Jayhawks men's basketball team'
# Pulling data from MediaWiki API: '2011 Atlantic 10 Men's Basketball Tournament'
# Pulling data from MediaWiki API: '2011 NCAA Men's Division I Basketball Tournament'
# Pulling data from MediaWiki API: 'A cappella'
# Pulling data from MediaWiki API: 'Afroman'
# Pulling data from MediaWiki API: 'Alcoa'
# Pulling data from MediaWiki API: 'Alpha Kappa Alpha'
# Pulling data from MediaWiki API: 'Alpha Phi Alpha'
# Pulling data from MediaWiki API: 'Alpha Phi Omega'
# Pulling data from MediaWiki API: 'Altria Group'
# Pulling data from MediaWiki API: 'Aluminum'
# Pulling data from MediaWiki API: 'Alumnus'
# Pulling data from MediaWiki API: 'American Civil War'
# Pulling data from MediaWiki API: 'American Jobs Act'
# Pulling data from MediaWiki API: 'Appalachian College of Pharmacy'
# Pulling data from MediaWiki API: 'Appalachian School of Law'
# Pulling data from MediaWiki API: 'Associated Colleges of the South'
# Pulling data from MediaWiki API: 'Athletic nickname'
# Pulling data from MediaWiki API: 'Atlantic 10 Conference'
# Pulling data from MediaWiki API: 'Atlantic University'
# Pulling data from MediaWiki API: 'Auburn University'
# Pulling data from MediaWiki API: 'Averett University'
# Pulling data from MediaWiki API: 'Baptist Theological Seminary at Richmond'
# Pulling data from MediaWiki API: 'Baptists'
# Pulling data from MediaWiki API: 'Barracks'
# Pulling data from MediaWiki API: 'Baylor University'
# Pulling data from MediaWiki API: 'Bill Clinton'
# Pulling data from MediaWiki API: 'Birmingham–Southern College'
# Pulling data from MediaWiki API: 'Blackstone College for Girls'
# Pulling data from MediaWiki API: 'Bluefield College'
# Pulling data from MediaWiki API: 'Bon Secours Memorial College of Nursing'
# Pulling data from MediaWiki API: 'Bonner Scholars'
# Pulling data from MediaWiki API: 'Bridgewater College'
# Pulling data from MediaWiki API: 'BusinessWeek'
# Pulling data from MediaWiki API: 'Capital City Classic'
# Pulling data from MediaWiki API: 'Capital Cup'
# Pulling data from MediaWiki API: 'Catholic University of America'
# Pulling data from MediaWiki API: 'Centenary College of Louisiana'
# Pulling data from MediaWiki API: 'Centre College'
# Pulling data from MediaWiki API: 'Chancellor (education)'
# Pulling data from MediaWiki API: 'Charles Gillette'
# Pulling data from MediaWiki API: 'Christendom College'
# Pulling data from MediaWiki API: 'Christopher Newport University'
# Pulling data from MediaWiki API: 'Clemson University'
# Pulling data from MediaWiki API: 'College'
# Pulling data from MediaWiki API: 'College football'
# Pulling data from MediaWiki API: 'College of William & Mary'
# Pulling data from MediaWiki API: 'Collegiate gothic'
# Pulling data from MediaWiki API: 'Columbia (Richmond, Virginia)'
# Pulling data from MediaWiki API: 'Commander in Chief (television)'
# Pulling data from MediaWiki API: 'Confederate States of America'
# Pulling data from MediaWiki API: 'Cordoba University'
# Pulling data from MediaWiki API: 'Cornell University'
# Pulling data from MediaWiki API: 'Council of Independent Colleges'
# Pulling data from MediaWiki API: 'Cry Wolf (2005 film)'
# Pulling data from MediaWiki API: 'Davidson College'
# Pulling data from MediaWiki API: 'Davidson Wildcats'
# Pulling data from MediaWiki API: 'Dawson's Creek'
# Pulling data from MediaWiki API: 'Dayton Flyers'
# Pulling data from MediaWiki API: 'DeVry University'
# Pulling data from MediaWiki API: 'Delta Delta Delta'
# Pulling data from MediaWiki API: 'Delta Gamma'
# Pulling data from MediaWiki API: 'Delta Sigma Theta'
# Pulling data from MediaWiki API: 'Duke University'
# Pulling data from MediaWiki API: 'Duquesne Dukes'
# Pulling data from MediaWiki API: 'E. Bruce Heilman'
# Pulling data from MediaWiki API: 'E. Claiborne Robins School of Business'
# Pulling data from MediaWiki API: 'E. Claiborne Robins Sr'
# Pulling data from MediaWiki API: 'E. Claiborne Robins Stadium'
# Pulling data from MediaWiki API: 'ECPI University'
# Pulling data from MediaWiki API: 'East Carolina University'
# Pulling data from MediaWiki API: 'Eastern Mennonite University'
# Pulling data from MediaWiki API: 'Eastern Virginia Medical School'
# Pulling data from MediaWiki API: 'Edward Via College of Osteopathic Medicine'
# Pulling data from MediaWiki API: 'Eighth blackbird'
# Pulling data from MediaWiki API: 'Elizabeth College (Virginia)'
# Pulling data from MediaWiki API: 'Emory and Henry College'
# Pulling data from MediaWiki API: 'Ferrum College'
# Pulling data from MediaWiki API: 'Financial endowment'
# Pulling data from MediaWiki API: 'Flo Rida'
# Pulling data from MediaWiki API: 'Florida Atlantic University'
# Pulling data from MediaWiki API: 'Florida Institute of Technology'
# Pulling data from MediaWiki API: 'Florida International University'
# Pulling data from MediaWiki API: 'Florida State University'
# Pulling data from MediaWiki API: 'Fordham Rams'
# Pulling data from MediaWiki API: 'Frederic W. Boatwright'
# Pulling data from MediaWiki API: 'Frederick College'
# Pulling data from MediaWiki API: 'Frederick Law Olmsted'
# Pulling data from MediaWiki API: 'Furman University'
# Pulling data from MediaWiki API: 'Geena Davis'
# Pulling data from MediaWiki API: 'Geographic coordinate system'
# Pulling data from MediaWiki API: 'George H. W. Bush'
# Pulling data from MediaWiki API: 'George Mason Patriots'
# Pulling data from MediaWiki API: 'George Mason University'
# Pulling data from MediaWiki API: 'George Washington Colonials'
# Pulling data from MediaWiki API: 'George Washington University'
# Pulling data from MediaWiki API: 'George Washington University Virginia Science & Technology Campus'
# Pulling data from MediaWiki API: 'Georgetown University'
# Pulling data from MediaWiki API: 'Georgia Institute of Technology'
# Pulling data from MediaWiki API: 'Georgia State University'
# Pulling data from MediaWiki API: 'Gibbs College'
# Pulling data from MediaWiki API: 'Goochland County, Virginia'
# Pulling data from MediaWiki API: 'Gordon Bunshaft'
# Pulling data from MediaWiki API: 'Gottwald Center for the Sciences'
# Pulling data from MediaWiki API: 'Governor's Schools (Virginia)'
# Pulling data from MediaWiki API: 'H. Gerald Quigg'
# Pulling data from MediaWiki API: 'Habitat for Humanity'
# Pulling data from MediaWiki API: 'Hampden–Sydney College'
# Pulling data from MediaWiki API: 'Hampton University'
# Pulling data from MediaWiki API: 'Hartland Institute'
# Pulling data from MediaWiki API: 'Hendrix College'
# Pulling data from MediaWiki API: 'Henrico County, Virginia'
# Pulling data from MediaWiki API: 'Henry Mansfield Cannon Memorial Chapel'
# Pulling data from MediaWiki API: 'Hollins University'
# Pulling data from MediaWiki API: 'Honor code'
# Pulling data from MediaWiki API: 'Idaho State University'
# Pulling data from MediaWiki API: 'International Standard Book Number'
# Pulling data from MediaWiki API: 'James Madison University'
# Pulling data from MediaWiki API: 'Jefferson College of Health Sciences'
# Pulling data from MediaWiki API: 'Jefferson Hotel (Richmond, Virginia)'
# Pulling data from MediaWiki API: 'Jepson School of Leadership Studies'
# Pulling data from MediaWiki API: 'John Leland Center for Theological Studies'
# Pulling data from MediaWiki API: 'Joint Forces Staff College'
# Pulling data from MediaWiki API: 'Kappa Alpha Order'
# Pulling data from MediaWiki API: 'Kappa Alpha Theta'
# Pulling data from MediaWiki API: 'Kappa Delta'
# Pulling data from MediaWiki API: 'Kappa Kappa Gamma'
# Pulling data from MediaWiki API: 'La Salle Explorers'
# Pulling data from MediaWiki API: 'Lambda Chi Alpha'
# Pulling data from MediaWiki API: 'Latin'
# Pulling data from MediaWiki API: 'Leadership Studies'
# Pulling data from MediaWiki API: 'Liberal arts'
# Pulling data from MediaWiki API: 'Liberty University'
# Pulling data from MediaWiki API: 'List of University of Richmond people'
# Pulling data from MediaWiki API: 'List of colleges and universities in Virginia'
# Pulling data from MediaWiki API: 'Longwood University'
# Pulling data from MediaWiki API: 'Louisiana State University'
# Pulling data from MediaWiki API: 'Louisiana Tech University'
# Pulling data from MediaWiki API: 'Mackenzie Allen'
# Pulling data from MediaWiki API: 'Malcolm U. Pitt Field'
# Pulling data from MediaWiki API: 'Marine Corps University'
# Pulling data from MediaWiki API: 'Marion College, Virginia'
# Pulling data from MediaWiki API: 'Mary Baldwin University'
# Pulling data from MediaWiki API: 'Marymount University'
# Pulling data from MediaWiki API: 'Massachusetts Institute of Technology'
# Pulling data from MediaWiki API: 'Mid-Atlantic States'
# Pulling data from MediaWiki API: 'Millsaps College'
# Pulling data from MediaWiki API: 'Mississippi State University'
# Pulling data from MediaWiki API: 'Model United Nations'
# Pulling data from MediaWiki API: 'Morehouse College'
# Pulling data from MediaWiki API: 'NCAA Division I'
# Pulling data from MediaWiki API: 'NCAA Division I Football Championship'
# Pulling data from MediaWiki API: 'National Public Radio'
# Pulling data from MediaWiki API: 'National Register of Historic Places'
# Pulling data from MediaWiki API: 'National Science Foundation'
# Pulling data from MediaWiki API: 'Need-blind admission'
# Pulling data from MediaWiki API: 'New England'
# Pulling data from MediaWiki API: 'Nonsectarian'
# Pulling data from MediaWiki API: 'Norfolk State University'
# Pulling data from MediaWiki API: 'North Carolina A&T State University'
# Pulling data from MediaWiki API: 'North Carolina State University'
# Pulling data from MediaWiki API: 'North Court'
# Pulling data from MediaWiki API: 'Ohio University'
# Pulling data from MediaWiki API: 'Old Dominion University'
# Pulling data from MediaWiki API: 'Patrick Henry College'
# Pulling data from MediaWiki API: 'Phi Beta Kappa'
# Pulling data from MediaWiki API: 'Phi Gamma Delta'
# Pulling data from MediaWiki API: 'Philip Morris USA'
# Pulling data from MediaWiki API: 'Pi Beta Phi'
# Pulling data from MediaWiki API: 'Postgraduate education'
# Pulling data from MediaWiki API: 'President Obama'
# Pulling data from MediaWiki API: 'President of the University of Richmond'
# Pulling data from MediaWiki API: 'Princeton University'
# Pulling data from MediaWiki API: 'Private school'
# Pulling data from MediaWiki API: 'Private university'
# Pulling data from MediaWiki API: 'Radford University'
# Pulling data from MediaWiki API: 'Ralph Adams Cram'
# Pulling data from MediaWiki API: 'Randolph College'
# Pulling data from MediaWiki API: 'Randolph–Macon College'
# Pulling data from MediaWiki API: 'Regent University'
# Pulling data from MediaWiki API: 'Reynolds Metals Company International Headquarters'
# Pulling data from MediaWiki API: 'Rhode Island Rams'
# Pulling data from MediaWiki API: 'Rhodes College'
# Pulling data from MediaWiki API: 'Rice University'
# Pulling data from MediaWiki API: 'Richard Bland College'
# Pulling data from MediaWiki API: 'Richmond, Virginia'
# Pulling data from MediaWiki API: 'Richmond Spiders'
# Pulling data from MediaWiki API: 'Richmond Spiders baseball'
# Pulling data from MediaWiki API: 'Richmond Spiders football'
# Pulling data from MediaWiki API: 'Richmond Spiders men's basketball'
# Pulling data from MediaWiki API: 'Richmond Spiders men's lacrosse'
# Pulling data from MediaWiki API: 'Richmond Spiders women's basketball'
# Pulling data from MediaWiki API: 'Roanoke College'
# Pulling data from MediaWiki API: 'Robins Center'
# Pulling data from MediaWiki API: 'Rollins College'
# Pulling data from MediaWiki API: 'Ronald Crutcher'
# Pulling data from MediaWiki API: 'Ross Perot'
# Pulling data from MediaWiki API: 'Ryland Hall (Richmond, Virginia)'
# Pulling data from MediaWiki API: 'Saint Joseph's Hawks'
# Pulling data from MediaWiki API: 'Saint Louis Billikens'
# Pulling data from MediaWiki API: 'Saint Paul's College (Virginia)'
# Pulling data from MediaWiki API: 'School colors'
# Pulling data from MediaWiki API: 'Sewanee: The University of the South'
# Pulling data from MediaWiki API: 'Shanghai Quartet'
# Pulling data from MediaWiki API: 'Shenandoah University'
# Pulling data from MediaWiki API: 'Sigma Chi'
# Pulling data from MediaWiki API: 'Sigma Phi Epsilon'
# Pulling data from MediaWiki API: 'SmartMoney'
# Pulling data from MediaWiki API: 'Southeastern Universities Research Association'
# Pulling data from MediaWiki API: 'Southern Virginia University'
# Pulling data from MediaWiki API: 'Southwestern University'
# Pulling data from MediaWiki API: 'Spelman College'
# Pulling data from MediaWiki API: 'Spider'
# Pulling data from MediaWiki API: 'St. Bonaventure Bonnies'
# Pulling data from MediaWiki API: 'Stratford University'
# Pulling data from MediaWiki API: 'Student financial aid (United States)'
# Pulling data from MediaWiki API: 'Study abroad'
# Pulling data from MediaWiki API: 'Suburban'
# Pulling data from MediaWiki API: 'Sullins College'
# Pulling data from MediaWiki API: 'Sweet Briar College'
# Pulling data from MediaWiki API: 'Texas A&M University'
# Pulling data from MediaWiki API: 'The Art Institute of Washington'
# Pulling data from MediaWiki API: 'The Art Institutes'
# Pulling data from MediaWiki API: 'The Collegian (University of Richmond)'
# Pulling data from MediaWiki API: 'The Princeton Review'
# Pulling data from MediaWiki API: 'The West End (Richmond, Virginia)'
# Pulling data from MediaWiki API: 'Theta Chi'
# Pulling data from MediaWiki API: 'Trinity University (Texas)'
# Pulling data from MediaWiki API: 'Trustee'
# Pulling data from MediaWiki API: 'Tulane University'
# Pulling data from MediaWiki API: 'U.S. News and World Report'
# Pulling data from MediaWiki API: 'UMass Minutemen and Minutewomen'
# Pulling data from MediaWiki API: 'Undergraduate education'
# Pulling data from MediaWiki API: 'Union (American Civil War)'
# Pulling data from MediaWiki API: 'Union Presbyterian Seminary'
# Pulling data from MediaWiki API: 'University of Alabama'
# Pulling data from MediaWiki API: 'University of Alabama at Birmingham'
# Pulling data from MediaWiki API: 'University of Alabama in Huntsville'
# Pulling data from MediaWiki API: 'University of Arkansas'
# Pulling data from MediaWiki API: 'University of Central Florida'
# Pulling data from MediaWiki API: 'University of Delaware'
# Pulling data from MediaWiki API: 'University of Florida'
# Pulling data from MediaWiki API: 'University of Georgia'
# Pulling data from MediaWiki API: 'University of Houston'
# Pulling data from MediaWiki API: 'University of Kentucky'
# Pulling data from MediaWiki API: 'University of Louisiana at Lafayette'
# Pulling data from MediaWiki API: 'University of Lynchburg'
# Pulling data from MediaWiki API: 'University of Management and Technology (United States)'
# Pulling data from MediaWiki API: 'University of Mary Washington'
# Pulling data from MediaWiki API: 'University of Maryland, Baltimore County'
# Pulling data from MediaWiki API: 'University of Maryland, College Park'
# Pulling data from MediaWiki API: 'University of Massachusetts Amherst'
# Pulling data from MediaWiki API: 'University of Memphis'
# Pulling data from MediaWiki API: 'University of Miami'
# Pulling data from MediaWiki API: 'University of Mississippi'
# Pulling data from MediaWiki API: 'University of New Orleans'
# Pulling data from MediaWiki API: 'University of North Carolina at Chapel Hill'
# Pulling data from MediaWiki API: 'University of Northern Virginia'
# Pulling data from MediaWiki API: 'University of Oklahoma'
# Pulling data from MediaWiki API: 'University of Regina'
# Pulling data from MediaWiki API: 'University of Richmond School of Law'
# Pulling data from MediaWiki API: 'University of Richmond School of Professional & Continuing Studies'
# Pulling data from MediaWiki API: 'University of South Carolina'
# Pulling data from MediaWiki API: 'University of South Florida'
# Pulling data from MediaWiki API: 'University of Southern Mississippi'
# Pulling data from MediaWiki API: 'University of Tennessee'
# Pulling data from MediaWiki API: 'University of Texas at Austin'
# Pulling data from MediaWiki API: 'University of Virginia'
# Pulling data from MediaWiki API: 'University of Virginia's College at Wise'
# Pulling data from MediaWiki API: 'University of the Potomac'
# Pulling data from MediaWiki API: 'University president'
# Pulling data from MediaWiki API: 'V-12 Navy College Training Program'
# Pulling data from MediaWiki API: 'VCU Rams'
# Pulling data from MediaWiki API: 'Vanderbilt University'
# Pulling data from MediaWiki API: 'Vice President of the United States'
# Pulling data from MediaWiki API: 'Virginia'
# Pulling data from MediaWiki API: 'Virginia Commonwealth University'
# Pulling data from MediaWiki API: 'Virginia Community College System'
# Pulling data from MediaWiki API: 'Virginia Intermont College'
# Pulling data from MediaWiki API: 'Virginia International University'
# Pulling data from MediaWiki API: 'Virginia Military Institute'
# Pulling data from MediaWiki API: 'Virginia State University'
# Pulling data from MediaWiki API: 'Virginia Tech'
# Pulling data from MediaWiki API: 'Virginia Theological Seminary'
# Pulling data from MediaWiki API: 'Virginia Union University'
# Pulling data from MediaWiki API: 'Virginia University of Lynchburg'
# Pulling data from MediaWiki API: 'Virginia Wesleyan University'
# Pulling data from MediaWiki API: 'Virginia–Maryland College of Veterinary Medicine'
# Pulling data from MediaWiki API: 'WDCE'
# Pulling data from MediaWiki API: 'Warren H. Manning'
# Pulling data from MediaWiki API: 'Warren Manning'
# Pulling data from MediaWiki API: 'Washington and Lee University'
# Pulling data from MediaWiki API: 'West Virginia University'
# Pulling data from MediaWiki API: 'Westwood College'
# Pulling data from MediaWiki API: 'Williams College'
# Pulling data from MediaWiki API: 'World War II'

# %% [markdown]
# ### Using the MediaWiki data
#
# Now, finally, we have the code and functionality to look at a
# collection of Wikipedia pages. Let's start with a simple task
# of counting how many links all of the pages linked from the Richmond
# site have. Pay attention to how I do this!

# %%
num_links = []
data_json = wiki.get_wiki_json("University of Richmond")
ur_links = wiki.links_as_list(data_json)

for link in ur_links:
    data = wiki.get_wiki_json(link)
    new_links = wiki.links_as_list(data)
    num_links.append(len(new_links))

# %% [markdown]
# Now, let's look at the results:

# %%
print(num_links)
# Out:
# [218, 183, 1, 208, 108, 1, 273, 52, 118, 624, 690, 198, 1, 2, 22, 1223, 267, 111, 176, 33, 54, 250, 98, 506, 179, 92, 770, 123, 625, 1618, 447, 99, 286, 94, 1, 181, 1, 81, 274, 486, 349, 475, 144, 44, 212, 322, 439, 369, 787, 611, 1, 169, 1, 930, 98, 916, 18, 32, 427, 218, 526, 308, 297, 381, 364, 401, 802, 604, 30, 48, 14, 240, 15, 347, 212, 155, 318, 1, 96, 420, 251, 134, 262, 379, 237, 612, 791, 462, 25, 8, 283, 338, 373, 286, 2026, 277, 500, 200, 829, 181, 793, 702, 293, 62, 418, 137, 1, 32, 16, 89, 547, 643, 202, 432, 429, 171, 453, 1, 228, 528, 465, 91, 176, 61, 126, 208, 282, 442, 318, 271, 169, 291, 683, 1, 1, 410, 206, 535, 358, 679, 428, 1, 121, 213, 91, 284, 276, 1122, 1, 400, 349, 159, 540, 494, 364, 2, 249, 232, 175, 1953, 75, 436, 460, 470, 171, 397, 446, 155, 152, 258, 109, 267, 248, 3, 36, 827, 274, 392, 330, 219, 506, 592, 345, 101, 102, 544, 699, 206, 1129, 250, 88, 184, 198, 16, 48, 507, 105, 419, 22, 479, 171, 227, 185, 369, 41, 359, 280, 227, 372, 263, 99, 71, 267, 531, 554, 570, 244, 168, 92, 1, 3, 114, 516, 732, 104, 75, 29, 97, 1, 265, 506, 124, 491, 1, 358, 227, 574, 297, 546, 351, 302, 552, 569, 348, 751, 675, 237, 507, 266, 179, 88, 318, 429, 741, 458, 455, 563, 365, 295, 644, 119, 591, 266, 131, 28, 559, 328, 264, 427, 824, 956, 269, 99, 1, 466, 233, 898, 845, 1461, 388, 104, 188, 91, 768, 354, 614, 306, 617, 375, 232, 367, 115, 61, 1, 733, 463, 224, 450, 1453]

# %% [markdown]
# What can we do with this? For starters, what's the average
# number of links on each page?

# %%
sum(num_links) / len(num_links)
# Out:
# 330.9397993311037

# %% [markdown]
# How does this compare to the number of links from the Richmond site?

# %%
len(ur_links)
# Out:
# 299

# %% [markdown]
# **Answer**:

# %% [markdown]
# ## Practice
#
# Take a look at the Wikipedia page on Richmond, Virginia:
#
# > https://en.wikipedia.org/wiki/Richmond,_Virginia
#
# Below, write code that:
#
# 1. Downloads all of the links from the Rock and Roll Hall of Fame
# Wikipedia page.
# 2. Then, extract from each page all of the links from **that** page
# and puts them together in one appended list called `all_links`.
# 3. Use the `collections.Counter` object to find the 40 links that
# are used most across all of the pages.
# 4. Think about the most frequent 40 pages and try to reason why
# these are the most common.

# %%
# Make sure all of the links are downloaded
data_json = wiki.get_wiki_json("Richmond,_Virginia")
rr_links = wiki.links_as_list(data_json)

for link in rr_links:
    data = wiki.get_wiki_json(link)
# Out:
# Pulling data from MediaWiki API: 'Kansas'
# Pulling data from MediaWiki API: 'Kentucky'
# Pulling data from MediaWiki API: 'King George County, Virginia'
# Pulling data from MediaWiki API: 'King William County, Virginia'
# Pulling data from MediaWiki API: 'King and Queen County, Virginia'
# Pulling data from MediaWiki API: 'Kingsport–Bristol–Bristol, Tennessee-Virginia Metropolitan Statistical Area'
# Pulling data from MediaWiki API: 'Laburnum Park Historic District'
# Pulling data from MediaWiki API: 'Lancaster County, Virginia'
# Pulling data from MediaWiki API: 'Lansing, Michigan'
# Pulling data from MediaWiki API: 'Law of Virginia'
# Pulling data from MediaWiki API: 'Lee County, Virginia'
# Pulling data from MediaWiki API: 'Lexington, Virginia'
# Pulling data from MediaWiki API: 'Libby Hill, Richmond'
# Pulling data from MediaWiki API: 'Lincoln, Nebraska'
# Pulling data from MediaWiki API: 'List of National Historic Landmarks in Virginia'
# Pulling data from MediaWiki API: 'List of United States Representatives from Virginia'
# Pulling data from MediaWiki API: 'List of United States Senators from Virginia'
# Pulling data from MediaWiki API: 'List of Virginia state parks'
# Pulling data from MediaWiki API: 'List of Virginia state symbols'
# Pulling data from MediaWiki API: 'List of counties in Virginia'
# Pulling data from MediaWiki API: 'List of newspapers in Virginia'
# Pulling data from MediaWiki API: 'List of people from Virginia'
# Pulling data from MediaWiki API: 'List of professional sports teams in Virginia'
# Pulling data from MediaWiki API: 'List of radio stations in Virginia'
# Pulling data from MediaWiki API: 'List of regions of the United States'
# Pulling data from MediaWiki API: 'List of rivers of Virginia'
# Pulling data from MediaWiki API: 'List of television stations in Virginia'
# Pulling data from MediaWiki API: 'Little Rock, Arkansas'
# Pulling data from MediaWiki API: 'Lockgreen'
# Pulling data from MediaWiki API: 'Loudoun County, Virginia'
# Pulling data from MediaWiki API: 'Louisa County, Virginia'
# Pulling data from MediaWiki API: 'Louisiana'
# Pulling data from MediaWiki API: 'Lunenburg County, Virginia'
# Pulling data from MediaWiki API: 'Lynchburg metropolitan area'
# Pulling data from MediaWiki API: 'MSNBC'
# Pulling data from MediaWiki API: 'Madison, Wisconsin'
# Pulling data from MediaWiki API: 'Madison County, Virginia'
# Pulling data from MediaWiki API: 'Main Street Banking Historic District'
# Pulling data from MediaWiki API: 'Maine'
# Pulling data from MediaWiki API: 'Malvern Gardens'
# Pulling data from MediaWiki API: 'Manassas, Virginia'
# Pulling data from MediaWiki API: 'Manassas Park, Virginia'
# Pulling data from MediaWiki API: 'Manchester, Richmond, Virginia'
# Pulling data from MediaWiki API: 'Martinsville, Virginia'
# Pulling data from MediaWiki API: 'Martinsville, Virginia micropolitan area'
# Pulling data from MediaWiki API: 'Maryland'
# Pulling data from MediaWiki API: 'Massachusetts'
# Pulling data from MediaWiki API: 'Mathews County, Virginia'
# Pulling data from MediaWiki API: 'Maymont Park'
# Pulling data from MediaWiki API: 'Mecklenburg County, Virginia'
# Pulling data from MediaWiki API: 'Michigan'
# Pulling data from MediaWiki API: 'Middle Peninsula'
# Pulling data from MediaWiki API: 'Middlesex County, Virginia'
# Pulling data from MediaWiki API: 'Minnesota'
# Pulling data from MediaWiki API: 'Mississippi'
# Pulling data from MediaWiki API: 'Missouri'
# Pulling data from MediaWiki API: 'Monroe Ward'
# Pulling data from MediaWiki API: 'Montana'
# Pulling data from MediaWiki API: 'Montgomery County, Virginia'
# Pulling data from MediaWiki API: 'Montpelier, Vermont'
# Pulling data from MediaWiki API: 'Museum District, Richmond, Virginia'
# Pulling data from MediaWiki API: 'Music of Virginia'
# Pulling data from MediaWiki API: 'Nashville, Tennessee'
# Pulling data from MediaWiki API: 'National Archives and Records Administration'
# Pulling data from MediaWiki API: 'National Oceanic and Atmospheric Administration'
# Pulling data from MediaWiki API: 'Native American tribes in Virginia'
# Pulling data from MediaWiki API: 'Near West End'
# Pulling data from MediaWiki API: 'Nebraska'
# Pulling data from MediaWiki API: 'Nelson County, Virginia'
# Pulling data from MediaWiki API: 'Nevada'
# Pulling data from MediaWiki API: 'New Hampshire'
# Pulling data from MediaWiki API: 'New Jersey'
# Pulling data from MediaWiki API: 'New Mexico'
# Pulling data from MediaWiki API: 'New York (state)'
# Pulling data from MediaWiki API: 'New York Times'
# Pulling data from MediaWiki API: 'Nielsen Media Research'
# Pulling data from MediaWiki API: 'North Carolina'
# Pulling data from MediaWiki API: 'North Dakota'
# Pulling data from MediaWiki API: 'Northampton County, Virginia'
# Pulling data from MediaWiki API: 'Northern Mariana Islands'
# Pulling data from MediaWiki API: 'Northern Neck'
# Pulling data from MediaWiki API: 'Northern Virginia'
# Pulling data from MediaWiki API: 'Northumberland County, Virginia'
# Pulling data from MediaWiki API: 'Norton, Virginia'
# Pulling data from MediaWiki API: 'Nottoway County, Virginia'
# Pulling data from MediaWiki API: 'Oakwood-Chimborazo Historic District'
# Pulling data from MediaWiki API: 'Oakwood–Chimborazo Historic District'
# Pulling data from MediaWiki API: 'Ohio'
# Pulling data from MediaWiki API: 'Oklahoma'
# Pulling data from MediaWiki API: 'Oklahoma City'
# Pulling data from MediaWiki API: 'Old Town Manchester'
# Pulling data from MediaWiki API: 'Olympia, Washington'
# Pulling data from MediaWiki API: 'Orange County, Virginia'
# Pulling data from MediaWiki API: 'Oregon'
# Pulling data from MediaWiki API: 'Page County, Virginia'
# Pulling data from MediaWiki API: 'Pago Pago'
# Pulling data from MediaWiki API: 'Patrick County, Virginia'
# Pulling data from MediaWiki API: 'Phoenix, Arizona'
# Pulling data from MediaWiki API: 'Pierre, South Dakota'
# Pulling data from MediaWiki API: 'Pine Camp, Richmond, Virginia'
# Pulling data from MediaWiki API: 'Pittsylvania County, Virginia'
# Pulling data from MediaWiki API: 'Politics of Virginia'
# Pulling data from MediaWiki API: 'Poquoson, Virginia'
# Pulling data from MediaWiki API: 'Portsmouth, Virginia'
# Pulling data from MediaWiki API: 'Prince Edward County, Virginia'
# Pulling data from MediaWiki API: 'Prince William County, Virginia'
# Pulling data from MediaWiki API: 'Providence, Rhode Island'
# Pulling data from MediaWiki API: 'Puerto Rico'
# Pulling data from MediaWiki API: 'Pulaski County, Virginia'
# Pulling data from MediaWiki API: 'Radford, Virginia'
# Pulling data from MediaWiki API: 'Randolph, Richmond, Virginia'
# Pulling data from MediaWiki API: 'Rappahannock County, Virginia'
# Pulling data from MediaWiki API: 'Rhode Island'
# Pulling data from MediaWiki API: 'Richmond.com'
# Pulling data from MediaWiki API: 'Richmond Times Dispatch'
# Pulling data from MediaWiki API: 'Ridge-and-Valley Appalachians'
# Pulling data from MediaWiki API: 'Roanoke County, Virginia'
# Pulling data from MediaWiki API: 'Roanoke metropolitan area'
# Pulling data from MediaWiki API: 'Rockbridge County, Virginia'
# Pulling data from MediaWiki API: 'Rocketts Landing'
# Pulling data from MediaWiki API: 'Rockingham County, Virginia'
# Pulling data from MediaWiki API: 'Russell County, Virginia'
# Pulling data from MediaWiki API: 'Sacramento, California'
# Pulling data from MediaWiki API: 'Saint Paul, Minnesota'
# Pulling data from MediaWiki API: 'Saipan'
# Pulling data from MediaWiki API: 'Salem, Oregon'
# Pulling data from MediaWiki API: 'Salem, Virginia'
# Pulling data from MediaWiki API: 'Salt Lake City'
# Pulling data from MediaWiki API: 'San Juan, Puerto Rico'
# Pulling data from MediaWiki API: 'Santa Fe, New Mexico'
# Pulling data from MediaWiki API: 'Sauer's Gardens'
# Pulling data from MediaWiki API: 'Scott County, Virginia'
# Pulling data from MediaWiki API: 'Scouting in Virginia'
# Pulling data from MediaWiki API: 'Shed Town'
# Pulling data from MediaWiki API: 'Shenandoah County, Virginia'
# Pulling data from MediaWiki API: 'Shenandoah Valley'
# Pulling data from MediaWiki API: 'Sherwood Park (Richmond, Virginia)'
# Pulling data from MediaWiki API: 'Smyth County, Virginia'
# Pulling data from MediaWiki API: 'South Carolina'
# Pulling data from MediaWiki API: 'South Dakota'
# Pulling data from MediaWiki API: 'South Hampton Roads'
# Pulling data from MediaWiki API: 'Southampton County, Virginia'
# Pulling data from MediaWiki API: 'Southern Living'
# Pulling data from MediaWiki API: 'Southside (Virginia)'
# Pulling data from MediaWiki API: 'Southwest Virginia'
# Pulling data from MediaWiki API: 'Spotsylvania County, Virginia'
# Pulling data from MediaWiki API: 'Springfield, Illinois'
# Pulling data from MediaWiki API: 'Stadium neighborhood'
# Pulling data from MediaWiki API: 'Stafford County, Virginia'
# Pulling data from MediaWiki API: 'State Fair of Virginia'
# Pulling data from MediaWiki API: 'Staunton, Virginia'
# Pulling data from MediaWiki API: 'Staunton–Waynesboro metropolitan area'
# Pulling data from MediaWiki API: 'Suffolk, Virginia'
# Pulling data from MediaWiki API: 'Surry County, Virginia'
# Pulling data from MediaWiki API: 'Sussex County, Virginia'
# Pulling data from MediaWiki API: 'Tallahassee, Florida'
# Pulling data from MediaWiki API: 'Tazewell County, Virginia'
# Pulling data from MediaWiki API: 'Tennessee'
# Pulling data from MediaWiki API: 'Tennessee Valley'
# Pulling data from MediaWiki API: 'Texas'
# Pulling data from MediaWiki API: 'Texas Beach'
# Pulling data from MediaWiki API: 'The Shops at Willow Lawn'
# Pulling data from MediaWiki API: 'The Virginian-Pilot'
# Pulling data from MediaWiki API: 'Three Chopt'
# Pulling data from MediaWiki API: 'Three Corners District'
# Pulling data from MediaWiki API: 'Tobacco Row, Richmond'
# Pulling data from MediaWiki API: 'Topeka, Kansas'
# Pulling data from MediaWiki API: 'Transportation in Virginia'
# Pulling data from MediaWiki API: 'Trenton, New Jersey'
# Pulling data from MediaWiki API: 'Tri-Cities, Virginia'
# Pulling data from MediaWiki API: 'U.S. Department of Commerce'
# Pulling data from MediaWiki API: 'U.S. News & World Report'
# Pulling data from MediaWiki API: 'Union Hill, Richmond, Virginia'
# Pulling data from MediaWiki API: 'United States Geological Survey'
# Pulling data from MediaWiki API: 'United States Supreme Court'
# Pulling data from MediaWiki API: 'United States Virgin Islands'
# Pulling data from MediaWiki API: 'United States congressional delegations from Virginia'
# Pulling data from MediaWiki API: 'Upper Shockoe Valley'
# Pulling data from MediaWiki API: 'Utah'
# Pulling data from MediaWiki API: 'VCU Greek Row'
# Pulling data from MediaWiki API: 'Vermont'
# Pulling data from MediaWiki API: 'Virginia's congressional districts'
# Pulling data from MediaWiki API: 'Virginia Beach, Virginia'
# Pulling data from MediaWiki API: 'Virginia Declaration of Rights'
# Pulling data from MediaWiki API: 'Virginia Peninsula'
# Pulling data from MediaWiki API: 'Virginia furniture'
# Pulling data from MediaWiki API: 'Virginia is for Lovers'
# Pulling data from MediaWiki API: 'Warren County, Virginia'
# Pulling data from MediaWiki API: 'Washington (state)'
# Pulling data from MediaWiki API: 'Washington County, Virginia'
# Pulling data from MediaWiki API: 'Washington Park, Richmond'
# Pulling data from MediaWiki API: 'Washington metropolitan area'
# Pulling data from MediaWiki API: 'Wayback Machine'
# Pulling data from MediaWiki API: 'Waynesboro, Virginia'
# Pulling data from MediaWiki API: 'WebCite'
# Pulling data from MediaWiki API: 'West Broad Street Commercial Historic District'
# Pulling data from MediaWiki API: 'West End (Richmond, Virginia)'
# Pulling data from MediaWiki API: 'West Virginia'
# Pulling data from MediaWiki API: 'West of the Boulevard'
# Pulling data from MediaWiki API: 'Western Virginia'
# Pulling data from MediaWiki API: 'Westmoreland County, Virginia'
# Pulling data from MediaWiki API: 'Winchester, VA–WV MSA'
# Pulling data from MediaWiki API: 'Winchester, Virginia'
# Pulling data from MediaWiki API: 'Wisconsin'
# Pulling data from MediaWiki API: 'Wise County, Virginia'
# Pulling data from MediaWiki API: 'Witcomb Court'
# Pulling data from MediaWiki API: 'Woodland Heights, Virginia'
# Pulling data from MediaWiki API: 'Wyoming'
# Pulling data from MediaWiki API: 'Wythe County, Virginia'
# Pulling data from MediaWiki API: 'York County, Virginia'

# %%
# Now, collect all of the links as a single list
all_links = []

for link in rr_links:
    data = wiki.get_wiki_json(link)
    new_links = wiki.links_as_list(data)
    all_links = all_links + new_links

# %%
# Now, count most frequent links
from collections import Counter

Counter(all_links).most_common(40)
# Out:
# [('Richmond, Virginia', 685),
#  ('Virginia', 576),
#  ('Geographic coordinate system', 479),
#  ('United States', 469),
#  ('International Standard Book Number', 446),
#  ('Wayback Machine', 334),
#  ('Norfolk, Virginia', 311),
#  ('United States Census Bureau', 306),
#  ('List of regions of the United States', 306),
#  ('Democratic Party (United States)', 297),
#  ('2010 United States Census', 294),
#  ('American Civil War', 285),
#  ('Republican Party (United States)', 285),
#  ('Washington, D.C.', 285),
#  ('Henrico County, Virginia', 282),
#  ('Petersburg, Virginia', 282),
#  ('2000 United States Census', 280),
#  ('1990 United States Census', 276),
#  ('1980 United States Census', 275),
#  ('1970 United States Census', 274),
#  ('List of National Historic Landmarks in Virginia', 274),
#  ('1960 United States Census', 272),
#  ('1950 United States Census', 269),
#  ('1930 United States Census', 268),
#  ('1940 United States Census', 267),
#  ('1920 United States Census', 266),
#  ('1910 United States Census', 265),
#  ('Chesterfield County, Virginia', 264),
#  ('1900 United States Census', 263),
#  ('U.S. state', 262),
#  ('1890 United States Census', 259),
#  ('Alexandria, Virginia', 259),
#  ('Charlottesville, Virginia', 255),
#  ('1880 United States Census', 251),
#  ('Roanoke, Virginia', 250),
#  ('Williamsburg, Virginia', 250),
#  ('Lynchburg, Virginia', 247),
#  ('Newport News, Virginia', 246),
#  ('Virginia Beach, Virginia', 242),
#  ('Fredericksburg, Virginia', 241)]

# %% [markdown]
# ## For next time
#
# On Tuesday we are going to start doing some network analysis. This means that we will
# need to use the **networkx** module, which is not included in the standard Anaconda
# Python installation. Please make sure that you have this downloaded correctly by running
# the following:

# %%
import networkx as nx

# %% [markdown]
# If there is a problem, please let me know before the end of class today.
